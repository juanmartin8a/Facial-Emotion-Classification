# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.layers import Activation
from keras.layers import Dropout
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, TensorBoard, ModelCheckpoint
from sklearn.metrics import accuracy_score

# %%
def load_data(dataset_path):

  data = []
  test_data = []
  test_labels = []
  labels =[]

  with open(dataset_path, 'r') as file:
      for line_no, line in enumerate(file.readlines()):
          if 0 < line_no <= 35887:
            curr_class, set_type, line = line.split(',')
            image_data = np.asarray([int(x) for x in line.split()]).reshape(48, 48)#Creating a list out of the string then converting it into a 2-Dimensional numpy array.
            image_data =image_data.astype(np.uint8)/255.0

            if (set_type.strip() == 'PrivateTest'):

              test_data.append(image_data)
              test_labels.append(curr_class)
            else:
              data.append(image_data)
              labels.append(curr_class)

      test_data = np.expand_dims(test_data, -1)
      test_labels = to_categorical(test_labels, num_classes = 7)
      data = np.expand_dims(data, -1)
      labels = to_categorical(labels, num_classes = 7)

      return np.array(data), np.array(labels), np.array(test_data), np.array(test_labels)

# %%
dataset_path = "icml_face_data.csv"
train_data, train_labels, test_data, test_labels = load_data(dataset_path)

print("Number of images in Training set:", len(train_data))
print("Number of images in Test set:", len(test_data))
# Out:
# Number of images in Training set: 32298
# Number of images in Test set: 3589

# %%
cnn = Sequential()

cnn.add(Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1), kernel_regularizer=l2(0.01)))
cnn.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
cnn.add(BatchNormalization())
cnn.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
cnn.add(Dropout(0.5))

cnn.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
cnn.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
cnn.add(BatchNormalization())
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.5))

cnn.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
cnn.add(BatchNormalization())
cnn.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
cnn.add(BatchNormalization())
cnn.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
cnn.add(BatchNormalization())
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.5))

cnn.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
cnn.add(BatchNormalization())
cnn.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
cnn.add(BatchNormalization())
cnn.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
cnn.add(BatchNormalization())
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.5))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))
cnn.add(Dropout(0.2))
cnn.add(Dense(1024, activation='relu'))
cnn.add(Dropout(0.2))
cnn.add(Dense(7, activation='softmax'))
adam = optimizers.Adam(lr = 0.001)
cnn.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])


lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3)
early_stopper = EarlyStopping(monitor='val_acc', min_delta=0, patience=6, mode='auto')
checkpointer = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5', monitor='val_loss', verbose=1, save_best_only=True)

#training
cnn.fit(
    train_data,
    train_labels,
    epochs = 50,
    batch_size = 32,
    validation_split = 0.2,
    shuffle = True,
    callbacks=[lr_reducer, checkpointer, early_stopper]
)
# Out:
# Epoch 1/50
# 808/808 [==============================] - 36s 34ms/step - loss: 2.2281 - accuracy: 0.2187 - val_loss: 1.7368 - val_accuracy: 0.3028
#
# Epoch 00001: val_loss improved from inf to 1.73679, saving model to /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 2/50
# 808/808 [==============================] - 27s 34ms/step - loss: 1.7034 - accuracy: 0.3281 - val_loss: 1.5781 - val_accuracy: 0.3704
#
# Epoch 00002: val_loss improved from 1.73679 to 1.57810, saving model to /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 3/50
# 808/808 [==============================] - 28s 34ms/step - loss: 1.5534 - accuracy: 0.3943 - val_loss: 1.5696 - val_accuracy: 0.3998
#
# Epoch 00003: val_loss improved from 1.57810 to 1.56957, saving model to /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 4/50
# 808/808 [==============================] - 27s 34ms/step - loss: 1.4408 - accuracy: 0.4463 - val_loss: 1.3940 - val_accuracy: 0.4624
#
# Epoch 00004: val_loss improved from 1.56957 to 1.39403, saving model to /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 5/50
# 808/808 [==============================] - 27s 34ms/step - loss: 1.3686 - accuracy: 0.4791 - val_loss: 1.4063 - val_accuracy: 0.4483
#
# Epoch 00005: val_loss did not improve from 1.39403
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 6/50
# 808/808 [==============================] - 27s 34ms/step - loss: 1.3196 - accuracy: 0.5011 - val_loss: 1.2423 - val_accuracy: 0.5269
#
# Epoch 00006: val_loss improved from 1.39403 to 1.24229, saving model to /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 7/50
# 808/808 [==============================] - 27s 34ms/step - loss: 1.2730 - accuracy: 0.5192 - val_loss: 1.2226 - val_accuracy: 0.5350
#
# Epoch 00007: val_loss improved from 1.24229 to 1.22260, saving model to /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 8/50
# 808/808 [==============================] - 27s 34ms/step - loss: 1.2139 - accuracy: 0.5511 - val_loss: 1.1385 - val_accuracy: 0.5641
#
# Epoch 00008: val_loss improved from 1.22260 to 1.13845, saving model to /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 9/50
# 808/808 [==============================] - 27s 34ms/step - loss: 1.1961 - accuracy: 0.5587 - val_loss: 1.1336 - val_accuracy: 0.5687
#
# Epoch 00009: val_loss improved from 1.13845 to 1.13356, saving model to /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 10/50
# 808/808 [==============================] - 27s 34ms/step - loss: 1.1569 - accuracy: 0.5712 - val_loss: 1.2431 - val_accuracy: 0.5365
#
# Epoch 00010: val_loss did not improve from 1.13356
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 11/50
# 808/808 [==============================] - 27s 34ms/step - loss: 1.1221 - accuracy: 0.5853 - val_loss: 1.1268 - val_accuracy: 0.5783
#
# Epoch 00011: val_loss improved from 1.13356 to 1.12677, saving model to /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 12/50
# 808/808 [==============================] - 27s 34ms/step - loss: 1.0840 - accuracy: 0.6001 - val_loss: 1.0748 - val_accuracy: 0.5971
#
# Epoch 00012: val_loss improved from 1.12677 to 1.07476, saving model to /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 13/50
# 808/808 [==============================] - 27s 34ms/step - loss: 1.0309 - accuracy: 0.6215 - val_loss: 1.0424 - val_accuracy: 0.6118
#
# Epoch 00013: val_loss improved from 1.07476 to 1.04240, saving model to /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 14/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.9954 - accuracy: 0.6319 - val_loss: 1.0852 - val_accuracy: 0.5967
#
# Epoch 00014: val_loss did not improve from 1.04240
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 15/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.9685 - accuracy: 0.6421 - val_loss: 1.1235 - val_accuracy: 0.6121
#
# Epoch 00015: val_loss did not improve from 1.04240
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 16/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.9126 - accuracy: 0.6661 - val_loss: 1.0909 - val_accuracy: 0.6167
#
# Epoch 00016: val_loss did not improve from 1.04240
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 17/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.8645 - accuracy: 0.6843 - val_loss: 1.1086 - val_accuracy: 0.6099
#
# Epoch 00017: val_loss did not improve from 1.04240
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 18/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.8296 - accuracy: 0.6978 - val_loss: 1.0914 - val_accuracy: 0.6255
#
# Epoch 00018: val_loss did not improve from 1.04240
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 19/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.7699 - accuracy: 0.7213 - val_loss: 1.2326 - val_accuracy: 0.5995
#
# Epoch 00019: val_loss did not improve from 1.04240
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 20/50
# 808/808 [==============================] - 28s 34ms/step - loss: 0.7246 - accuracy: 0.7401 - val_loss: 1.0411 - val_accuracy: 0.6365
#
# Epoch 00020: val_loss improved from 1.04240 to 1.04107, saving model to /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/Model/weights_facial.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 21/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.6786 - accuracy: 0.7557 - val_loss: 1.1014 - val_accuracy: 0.6333
#
# Epoch 00021: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 22/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.6420 - accuracy: 0.7688 - val_loss: 1.1597 - val_accuracy: 0.6322
#
# Epoch 00022: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 23/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.6068 - accuracy: 0.7794 - val_loss: 1.1489 - val_accuracy: 0.6300
#
# Epoch 00023: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 24/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.5569 - accuracy: 0.7996 - val_loss: 1.1785 - val_accuracy: 0.6458
#
# Epoch 00024: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 25/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.5159 - accuracy: 0.8146 - val_loss: 1.2613 - val_accuracy: 0.6432
#
# Epoch 00025: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 26/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.4880 - accuracy: 0.8238 - val_loss: 1.2743 - val_accuracy: 0.6283
#
# Epoch 00026: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 27/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.4498 - accuracy: 0.8392 - val_loss: 1.2958 - val_accuracy: 0.6293
#
# Epoch 00027: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 28/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.4048 - accuracy: 0.8548 - val_loss: 1.3048 - val_accuracy: 0.6418
#
# Epoch 00028: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 29/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.3915 - accuracy: 0.8646 - val_loss: 1.4723 - val_accuracy: 0.6337
#
# Epoch 00029: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 30/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.3714 - accuracy: 0.8740 - val_loss: 1.4303 - val_accuracy: 0.6437
#
# Epoch 00030: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 31/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.3332 - accuracy: 0.8820 - val_loss: 1.5082 - val_accuracy: 0.6466
#
# Epoch 00031: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 32/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.3095 - accuracy: 0.8917 - val_loss: 1.5206 - val_accuracy: 0.6480
#
# Epoch 00032: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 33/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.2870 - accuracy: 0.8988 - val_loss: 1.5771 - val_accuracy: 0.6481
#
# Epoch 00033: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 34/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.2806 - accuracy: 0.9009 - val_loss: 1.5997 - val_accuracy: 0.6389
#
# Epoch 00034: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 35/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.2572 - accuracy: 0.9119 - val_loss: 1.5426 - val_accuracy: 0.6485
#
# Epoch 00035: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 36/50
# 808/808 [==============================] - 27s 33ms/step - loss: 0.2325 - accuracy: 0.9193 - val_loss: 1.6440 - val_accuracy: 0.6502
#
# Epoch 00036: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 37/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.2160 - accuracy: 0.9276 - val_loss: 1.7460 - val_accuracy: 0.6381
#
# Epoch 00037: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 38/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.2048 - accuracy: 0.9299 - val_loss: 1.6370 - val_accuracy: 0.6367
#
# Epoch 00038: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 39/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.1883 - accuracy: 0.9348 - val_loss: 1.8240 - val_accuracy: 0.6373
#
# Epoch 00039: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 40/50
# 808/808 [==============================] - 28s 34ms/step - loss: 0.1833 - accuracy: 0.9376 - val_loss: 1.7273 - val_accuracy: 0.6421
#
# Epoch 00040: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 41/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.1730 - accuracy: 0.9422 - val_loss: 1.8671 - val_accuracy: 0.6444
#
# Epoch 00041: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 42/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.1639 - accuracy: 0.9451 - val_loss: 1.7719 - val_accuracy: 0.6359
#
# Epoch 00042: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 43/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.1482 - accuracy: 0.9497 - val_loss: 1.9574 - val_accuracy: 0.6412
#
# Epoch 00043: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 44/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.1451 - accuracy: 0.9528 - val_loss: 1.8355 - val_accuracy: 0.6433
#
# Epoch 00044: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 45/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.1477 - accuracy: 0.9507 - val_loss: 1.9099 - val_accuracy: 0.6467
#
# Epoch 00045: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 46/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.1386 - accuracy: 0.9550 - val_loss: 1.9260 - val_accuracy: 0.6440
#
# Epoch 00046: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 47/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.1257 - accuracy: 0.9590 - val_loss: 2.0935 - val_accuracy: 0.6512
#
# Epoch 00047: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 48/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.1222 - accuracy: 0.9610 - val_loss: 2.0485 - val_accuracy: 0.6443
#
# Epoch 00048: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 49/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.1099 - accuracy: 0.9645 - val_loss: 2.0280 - val_accuracy: 0.6447
#
# Epoch 00049: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 50/50
# 808/808 [==============================] - 27s 34ms/step - loss: 0.1174 - accuracy: 0.9622 - val_loss: 2.0724 - val_accuracy: 0.6492
#
# Epoch 00050: val_loss did not improve from 1.04107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr

# %%
predicted_test_labels = np.argmax(cnn.predict(test_data), axis=1)
test_labels = np.argmax(test_labels, axis=1)
print ("Accuracy score = ", accuracy_score(test_labels, predicted_test_labels))
# Out:
# Accuracy score =  0.6430760657564781

# %%
from keras.models import model_from_json
model_json = cnn.to_json()
with open("/content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/model_2.json", "w") as json_file:
    json_file.write(model_json)
cnn.save_weights("/content/drive/My Drive/Colab Notebooks/Facial Emotion Recognition/model_2.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
